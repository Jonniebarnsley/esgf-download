# %% [markdown]
# # Downloading from the ESGF archive
#
# This Notebook runs through all the steps to download CORDEX data from the Earth System Grid Federation archive, from a single dataset, to multiple ensembles including various models, variables, and experiments. Before you start, check out the README.md and ensure you have followed all the steps in the 'Setup' section.

# %%
import os
import ssl
import libs.downloader as dl
from pyesgf.logon import LogonManager
from pyesgf.search import SearchConnection

# %%
# define your query
query = {
    'project': 'CORDEX',
    'domain': 'EUR-11',
    'experiment': 'rcp85',
    'variable': 'tas',
    'time_frequency': 'mon',
    'ensemble': 'r1i1p1'
}

# ensure the following are saved as environment variables
USERNAME = os.environ['ESGF_USERNAME']
PASSWORD = os.environ['ESGF_PASSWORD']
DATA_PATH = os.environ['DATA_HOME']

# %%
# check ESGF for number of datasets that satisfy query
conn = SearchConnection('http://esgf-data.dkrz.de/esg-search', distrib=True)
context = conn.new_context(**query, facets=query.keys())
context.hit_count
# Out:
# 46

# %%
# login to ESGF and generate SSL context
myproxy_host = 'esgf-data.dkrz.de'

lm = LogonManager()
lm.logon(username=USERNAME, password=PASSWORD, hostname=myproxy_host)

sslcontext = ssl.create_default_context(purpose=ssl.Purpose.SERVER_AUTH)
sslcontext.load_verify_locations(capath=lm.esgf_certs_dir)
sslcontext.load_cert_chain(lm.esgf_credentials)

lm.is_logged_on()
# Out:
# True

# %%
# generate results and check an example dataset to verify all is working as expected
results = context.search()
example_dataset = results[0]
example_dataset.dataset_id
# Out:
# 'cordex.output.EUR-11.CLMcom.MPI-M-MPI-ESM-LR.rcp85.r1i1p1.CCLM4-8-17.v1.mon.tas.v20140515|esgf1.dkrz.de'

# %%
# and now an example file within that dataset, including its http download link
example_files = example_dataset.file_context().search(ignore_facet_check=True)
example_file = example_files[0]
example_file.download_url
# Out:
# 'http://esgf1.dkrz.de/thredds/fileServer/cordex/cordex/output/EUR-11/CLMcom/MPI-M-MPI-ESM-LR/rcp85/r1i1p1/CLMcom-CCLM4-8-17/v1/mon/tas/v20140515/tas_EUR-11_MPI-M-MPI-ESM-LR_rcp85_r1i1p1_CLMcom-CCLM4-8-17_v1_mon_200601-201012.nc'

# %%
# call download_ensemble on the context generated by your query
downloads = dl.download_ensemble(context, DATA_PATH, ssl=sslcontext, verbose=True)

# %%
# or make multiple queries at once

queries = {
    'project': ['CORDEX'],
    'domain': ['EUR-11'],
    'experiment': ['historical', 'rcp26', 'rcp85'],
    'variable': ['tas', 'pr'],
    'time_frequency': ['mon'],
    'ensemble': ['r1i1p1']
}

contexts = dl.make_multiple_queries(queries=queries, conn=conn)
# Out:
# querying ESGF...
# found the following datasets matching your queries:
#
# project        domain         experiment     variable       time_frequency ensemble        hit_count
# CORDEX         EUR-11         historical     tas            mon            r1i1p1          48
# CORDEX         EUR-11         historical     pr             mon            r1i1p1          48
# CORDEX         EUR-11         rcp26          tas            mon            r1i1p1          23
# CORDEX         EUR-11         rcp26          pr             mon            r1i1p1          23
# CORDEX         EUR-11         rcp85          tas            mon            r1i1p1          46
# CORDEX         EUR-11         rcp85          pr             mon            r1i1p1          46

# %%
# and then queue them to download one after the other
dl.download_multiple_ensembles(queries=queries, conn=conn, ssl=sslcontext, local_path=DATA_PATH)
# Out:
# querying ESGF...
# found the following datasets matching your queries:
#
# project        domain         experiment     variable       time_frequency ensemble        hit_count
# CORDEX         EUR-11         historical     tas            mon            r1i1p1          48
# CORDEX         EUR-11         historical     pr             mon            r1i1p1          48
# CORDEX         EUR-11         rcp26          tas            mon            r1i1p1          23
# CORDEX         EUR-11         rcp26          pr             mon            r1i1p1          23
# CORDEX         EUR-11         rcp85          tas            mon            r1i1p1          46
# CORDEX         EUR-11         rcp85          pr             mon            r1i1p1          46
#
# downloading next config: CORDEX EUR-11 historical tas mon r1i1p1 (48 total datasets)
# downloading 1 of 48: cordex.output.EUR-11.CLMcom.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1.CCLM4-8-17.v1.mon.tas.v20140515|esgf1.dkrz.de ---> done!
# downloading 2 of 48: cordex.output.EUR-11.CLMcom.MOHC-HadGEM2-ES.historical.r1i1p1.CCLM4-8-17.v1.mon.tas.v20150320|esgf1.dkrz.de ---> done!
# downloading 3 of 48: cordex.output.EUR-11.KNMI.ICHEC-EC-EARTH.historical.r1i1p1.RACMO22E.v1.mon.tas.v20140313|esgf1.dkrz.de ---> done!
# downloading 4 of 48: cordex.output.EUR-11.CLMcom.MPI-M-MPI-ESM-LR.historical.r1i1p1.CCLM4-8-17.v1.mon.tas.v20140515|esgf1.dkrz.de ---> done!
# downloading 5 of 48: cordex.output.EUR-11.KNMI.MOHC-HadGEM2-ES.historical.r1i1p1.RACMO22E.v2.mon.tas.v20160620|esgf1.dkrz.de ---> done!
# downloading 6 of 48: cordex.output.EUR-11.MPI-CSC.MPI-M-MPI-ESM-LR.historical.r1i1p1.REMO2009.v1.mon.tas.v20160419|esgf1.dkrz.de ---> done!
# downloading 7 of 48: cordex.output.EUR-11.RMIB-UGent.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1.ALARO-0.v1.mon.tas.v20170207|esgf1.dkrz.de ---> done!
# downloading 8 of 48: cordex.output.EUR-11.GERICS.NCC-NorESM1-M.historical.r1i1p1.REMO2015.v1.mon.tas.v20181107|esgf1.dkrz.de ---> done!
# downloading 9 of 48: cordex.output.EUR-11.GERICS.NOAA-GFDL-GFDL-ESM2G.historical.r1i1p1.REMO2015.v1.mon.tas.v20180710|esgf1.dkrz.de ---> done!
# downloading 10 of 48: cordex.output.EUR-11.GERICS.IPSL-IPSL-CM5A-LR.historical.r1i1p1.REMO2015.v1.mon.tas.v20180710|esgf1.dkrz.de ---> done!
# downloading 11 of 48: cordex.output.EUR-11.KNMI.MPI-M-MPI-ESM-LR.historical.r1i1p1.RACMO22E.v1.mon.tas.v20190619|esgf1.dkrz.de ---> done!
# downloading 12 of 48: cordex.output.EUR-11.DMI.NCC-NorESM1-M.historical.r1i1p1.HIRHAM5.v3.mon.tas.v20190522|cordexesg.dmi.dk ---> done!
# downloading 13 of 48: cordex.output.EUR-11.DMI.MOHC-HadGEM2-ES.historical.r1i1p1.HIRHAM5.v2.mon.tas.v20190512|cordexesg.dmi.dk ---> done!
# downloading 14 of 48: cordex.output.EUR-11.CLMcom-ETH.NCC-NorESM1-M.historical.r1i1p1.COSMO-crCLIM-v1-1.v1.mon.tas.v20191210|esgf1.dkrz.de ---> done!
# downloading 15 of 48: cordex.output.EUR-11.DMI.ICHEC-EC-EARTH.historical.r1i1p1.HIRHAM5.v1.mon.tas.v20190108|cordexesg.dmi.dk ---> done!
# downloading 16 of 48: cordex.output.EUR-11.KNMI.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1.RACMO22E.v2.mon.tas.v20181212|esgf1.dkrz.de ---> done!
# downloading 17 of 48: cordex.output.EUR-11.DMI.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1.HIRHAM5.v2.mon.tas.v20190131|cordexesg.dmi.dk ---> done!
# downloading 18 of 48: cordex.output.EUR-11.KNMI.NCC-NorESM1-M.historical.r1i1p1.RACMO22E.v1.mon.tas.v20190415|esgf1.dkrz.de ---> done!
# downloading 19 of 48: cordex.output.EUR-11.CLMcom-ETH.MPI-M-MPI-ESM-LR.historical.r1i1p1.COSMO-crCLIM-v1-1.v1.mon.tas.v20191219|esgf1.dkrz.de ---> done!
# downloading 20 of 48: cordex.output.EUR-11.DMI.MPI-M-MPI-ESM-LR.historical.r1i1p1.HIRHAM5.v1.mon.tas.v20191101|cordexesg.dmi.dk ---> done!
# downloading 21 of 48: cordex.output.EUR-11.KNMI.IPSL-IPSL-CM5A-MR.historical.r1i1p1.RACMO22E.v1.mon.tas.v20191029|esgf1.dkrz.de ---> done!
# downloading 22 of 48: cordex.output.EUR-11.CLMcom-ETH.MOHC-HadGEM2-ES.historical.r1i1p1.COSMO-crCLIM-v1-1.v1.mon.tas.v20200609|esgf1.dkrz.de ---> done!
# downloading 23 of 48: cordex.output.EUR-11.GERICS.IPSL-IPSL-CM5A-MR.historical.r1i1p1.REMO2015.v1.mon.tas.v20200702|esgf1.dkrz.de ---> done!
# downloading 24 of 48: cordex.output.EUR-11.GERICS.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1.REMO2015.v2.mon.tas.v20200713|esgf1.dkrz.de ---> done!
# downloading 25 of 48: cordex.output.EUR-11.DMI.IPSL-IPSL-CM5A-MR.historical.r1i1p1.HIRHAM5.v1.mon.tas.v20201101|cordexesg.dmi.dk ---> done!
# downloading 26 of 48: cordex.output.EUR-11.CLMcom-ETH.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1.COSMO-crCLIM-v1-1.v1.mon.tas.v20210308|esgf1.dkrz.de ---> done!
# downloading 27 of 48: cordex.output.EUR-11.CLMcom-ETH.ICHEC-EC-EARTH.historical.r1i1p1.COSMO-crCLIM-v1-1.v1.mon.tas.v20201215|esgf1.dkrz.de ---> done!
# downloading 28 of 48: cordex.output.EUR-11.MOHC.MOHC-HadGEM2-ES.historical.r1i1p1.HadREM3-GA7-05.v1.mon.tas.v20191005|esgf.ceda.ac.uk ---> done!
# downloading 29 of 48: cordex.output.EUR-11.MOHC.MOHC-HadGEM2-ES.historical.r1i1p1.HadREM3-GA7-05.v1.mon.tas.v20200330|esgf.ceda.ac.uk ---> done!
# downloading 30 of 48: cordex.output.EUR-11.MOHC.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1.HadREM3-GA7-05.v2.mon.tas.v20201111|esgf.ceda.ac.uk ---> done!
# downloading 31 of 48: cordex.output.EUR-11.MOHC.MPI-M-MPI-ESM-LR.historical.r1i1p1.HadREM3-GA7-05.v1.mon.tas.v20200330|esgf.ceda.ac.uk ---> done!
# downloading 32 of 48: cordex.output.EUR-11.MOHC.NCC-NorESM1-M.historical.r1i1p1.HadREM3-GA7-05.v1.mon.tas.v20200706|esgf.ceda.ac.uk ---> done!
# downloading 33 of 48: cordex.output.EUR-11.CNRM.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1.ALADIN53.v1.mon.tas.v20150127|esg1.umr-cnrm.fr ---> done!
# downloading 34 of 48: cordex.output.EUR-11.CNRM.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1.ALADIN63.v2.mon.tas.v20190121|esg1.umr-cnrm.fr ---> done!
# downloading 35 of 48: cordex.output.EUR-11.CNRM.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1.ALADIN63.v2.mon.tas.v20190510|esg1.umr-cnrm.fr ---> done!
# downloading 36 of 48: cordex.output.EUR-11.CNRM.MOHC-HadGEM2-ES.historical.r1i1p1.ALADIN63.v1.mon.tas.v20190919|esg1.umr-cnrm.fr ---> done!
# downloading 37 of 48: cordex.output.EUR-11.CNRM.MPI-M-MPI-ESM-LR.historical.r1i1p1.ALADIN63.v1.mon.tas.v20200306|esg1.umr-cnrm.fr ---> done!
# downloading 38 of 48: cordex.output.EUR-11.CNRM.NCC-NorESM1-M.historical.r1i1p1.ALADIN63.v1.mon.tas.v20201203|esg1.umr-cnrm.fr ---> done!
# downloading 39 of 48: cordex.output.EUR-11.SMHI.NCC-NorESM1-M.historical.r1i1p1.RCA4.v1.mon.tas.v20180820|esg-dn1.nsc.liu.se ---> done!
# downloading 40 of 48: cordex.output.EUR-11.SMHI.ICHEC-EC-EARTH.historical.r1i1p1.RCA4.v1.mon.tas.v20190820|esg-dn1.nsc.liu.se ---> done!
# downloading 41 of 48: cordex.output.EUR-11.ICTP.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1.RegCM4-6.v2.mon.tas.v20190502|esgf-ictp.hpc.cineca.it ---> done!
# downloading 42 of 48: cordex.output.EUR-11.ICTP.NCC-NorESM1-M.historical.r1i1p1.RegCM4-6.v1.mon.tas.v20190502|esgf-ictp.hpc.cineca.it ---> done!
# downloading 43 of 48: cordex.output.EUR-11.ICTP.MPI-M-MPI-ESM-LR.historical.r1i1p1.RegCM4-6.v1.mon.tas.v20190502|esgf-ictp.hpc.cineca.it ---> done!
# downloading 44 of 48: cordex.output.EUR-11.SMHI.MOHC-HadGEM2-ES.historical.r1i1p1.RCA4.v1.mon.tas.v20131026|esg-dn1.nsc.liu.se ---> done!
# downloading 45 of 48: cordex.output.EUR-11.SMHI.IPSL-IPSL-CM5A-MR.historical.r1i1p1.RCA4.v1.mon.tas.v20131026|esg-dn1.nsc.liu.se ---> done!
# downloading 46 of 48: cordex.output.EUR-11.SMHI.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1.RCA4.v1.mon.tas.v20131026|esg-dn1.nsc.liu.se ---> done!
# downloading 47 of 48: cordex.output.EUR-11.SMHI.MPI-M-MPI-ESM-LR.historical.r1i1p1.RCA4.v1a.mon.tas.v20160803|esg-dn1.nsc.liu.se ---> done!
# downloading 48 of 48: cordex.output.EUR-11.ICTP.MOHC-HadGEM2-ES.historical.r1i1p1.RegCM4-6.v1.mon.tas.v20190502|esgf-ictp.hpc.cineca.it ---> done!
#
# successfully downloaded 48 of 48 datasets
#
# downloading next config: CORDEX EUR-11 historical pr mon r1i1p1 (48 total datasets)
# downloading 1 of 48: cordex.output.EUR-11.CLMcom.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1.CCLM4-8-17.v1.mon.pr.v20140515|esgf1.dkrz.de ---> done!
# downloading 2 of 48: cordex.output.EUR-11.CLMcom.MOHC-HadGEM2-ES.historical.r1i1p1.CCLM4-8-17.v1.mon.pr.v20150320|esgf1.dkrz.de ---> done!
# downloading 3 of 48: cordex.output.EUR-11.CLMcom.MPI-M-MPI-ESM-LR.historical.r1i1p1.CCLM4-8-17.v1.mon.pr.v20140515|esgf1.dkrz.de ---> done!
# downloading 4 of 48: cordex.output.EUR-11.KNMI.ICHEC-EC-EARTH.historical.r1i1p1.RACMO22E.v1.mon.pr.v20140313|esgf1.dkrz.de ---> done!
# downloading 5 of 48: cordex.output.EUR-11.KNMI.MOHC-HadGEM2-ES.historical.r1i1p1.RACMO22E.v2.mon.pr.v20160620|esgf1.dkrz.de ---> done!
# downloading 6 of 48: cordex.output.EUR-11.MPI-CSC.MPI-M-MPI-ESM-LR.historical.r1i1p1.REMO2009.v1.mon.pr.v20160419|esgf1.dkrz.de ---> done!
# downloading 7 of 48: cordex.output.EUR-11.RMIB-UGent.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1.ALARO-0.v1.mon.pr.v20170207|esgf1.dkrz.de ---> done!
# downloading 8 of 48: cordex.output.EUR-11.GERICS.IPSL-IPSL-CM5A-LR.historical.r1i1p1.REMO2015.v1.mon.pr.v20180710|esgf1.dkrz.de ---> done!
# downloading 9 of 48: cordex.output.EUR-11.GERICS.NCC-NorESM1-M.historical.r1i1p1.REMO2015.v1.mon.pr.v20181107|esgf1.dkrz.de ---> done!
# downloading 10 of 48: cordex.output.EUR-11.GERICS.NOAA-GFDL-GFDL-ESM2G.historical.r1i1p1.REMO2015.v1.mon.pr.v20180710|esgf1.dkrz.de ---> done!
# downloading 11 of 48: cordex.output.EUR-11.KNMI.MPI-M-MPI-ESM-LR.historical.r1i1p1.RACMO22E.v1.mon.pr.v20190619|esgf1.dkrz.de ---> done!
# downloading 12 of 48: cordex.output.EUR-11.DMI.MOHC-HadGEM2-ES.historical.r1i1p1.HIRHAM5.v2.mon.pr.v20190512|cordexesg.dmi.dk ---> done!
# downloading 13 of 48: cordex.output.EUR-11.DMI.NCC-NorESM1-M.historical.r1i1p1.HIRHAM5.v3.mon.pr.v20190522|cordexesg.dmi.dk ---> done!
# downloading 14 of 48: cordex.output.EUR-11.CLMcom-ETH.NCC-NorESM1-M.historical.r1i1p1.COSMO-crCLIM-v1-1.v1.mon.pr.v20191210|esgf1.dkrz.de ---> done!
# downloading 15 of 48: cordex.output.EUR-11.DMI.ICHEC-EC-EARTH.historical.r1i1p1.HIRHAM5.v1.mon.pr.v20190108|cordexesg.dmi.dk ---> done!
# downloading 16 of 48: cordex.output.EUR-11.KNMI.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1.RACMO22E.v2.mon.pr.v20181212|esgf1.dkrz.de ---> done!
# downloading 17 of 48: cordex.output.EUR-11.DMI.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1.HIRHAM5.v2.mon.pr.v20190131|cordexesg.dmi.dk ---> done!
# downloading 18 of 48: cordex.output.EUR-11.KNMI.NCC-NorESM1-M.historical.r1i1p1.RACMO22E.v1.mon.pr.v20190415|esgf1.dkrz.de ---> done!
# downloading 19 of 48: cordex.output.EUR-11.CLMcom-ETH.MPI-M-MPI-ESM-LR.historical.r1i1p1.COSMO-crCLIM-v1-1.v1.mon.pr.v20191219|esgf1.dkrz.de ---> done!
# downloading 20 of 48: cordex.output.EUR-11.DMI.MPI-M-MPI-ESM-LR.historical.r1i1p1.HIRHAM5.v1.mon.pr.v20191101|cordexesg.dmi.dk ---> done!
# downloading 21 of 48: cordex.output.EUR-11.KNMI.IPSL-IPSL-CM5A-MR.historical.r1i1p1.RACMO22E.v1.mon.pr.v20191029|esgf1.dkrz.de ---> done!
# downloading 22 of 48: cordex.output.EUR-11.CLMcom-ETH.MOHC-HadGEM2-ES.historical.r1i1p1.COSMO-crCLIM-v1-1.v1.mon.pr.v20200609|esgf1.dkrz.de ---> done!
# downloading 23 of 48: cordex.output.EUR-11.GERICS.IPSL-IPSL-CM5A-MR.historical.r1i1p1.REMO2015.v1.mon.pr.v20200702|esgf1.dkrz.de ---> done!
# downloading 24 of 48: cordex.output.EUR-11.GERICS.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1.REMO2015.v2.mon.pr.v20200713|esgf1.dkrz.de ---> done!
# downloading 25 of 48: cordex.output.EUR-11.DMI.IPSL-IPSL-CM5A-MR.historical.r1i1p1.HIRHAM5.v1.mon.pr.v20201101|cordexesg.dmi.dk ---> done!
# downloading 26 of 48: cordex.output.EUR-11.CLMcom-ETH.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1.COSMO-crCLIM-v1-1.v1.mon.pr.v20210308|esgf1.dkrz.de ---> done!
# downloading 27 of 48: cordex.output.EUR-11.CLMcom-ETH.ICHEC-EC-EARTH.historical.r1i1p1.COSMO-crCLIM-v1-1.v1.mon.pr.v20201215|esgf1.dkrz.de ---> done!
# downloading 28 of 48: cordex.output.EUR-11.MOHC.MOHC-HadGEM2-ES.historical.r1i1p1.HadREM3-GA7-05.v1.mon.pr.v20191005|esgf.ceda.ac.uk ---> done!
# downloading 29 of 48: cordex.output.EUR-11.MOHC.MOHC-HadGEM2-ES.historical.r1i1p1.HadREM3-GA7-05.v1.mon.pr.v20200330|esgf.ceda.ac.uk ---> done!
# downloading 30 of 48: cordex.output.EUR-11.MOHC.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1.HadREM3-GA7-05.v2.mon.pr.v20201111|esgf.ceda.ac.uk ---> done!
# downloading 31 of 48: cordex.output.EUR-11.MOHC.MPI-M-MPI-ESM-LR.historical.r1i1p1.HadREM3-GA7-05.v1.mon.pr.v20200330|esgf.ceda.ac.uk ---> done!
# downloading 32 of 48: cordex.output.EUR-11.MOHC.NCC-NorESM1-M.historical.r1i1p1.HadREM3-GA7-05.v1.mon.pr.v20200706|esgf.ceda.ac.uk ---> done!
# downloading 33 of 48: cordex.output.EUR-11.CNRM.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1.ALADIN53.v1.mon.pr.v20150127|esg1.umr-cnrm.fr ---> done!
# downloading 34 of 48: cordex.output.EUR-11.CNRM.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1.ALADIN63.v2.mon.pr.v20190121|esg1.umr-cnrm.fr ---> done!
# downloading 35 of 48: cordex.output.EUR-11.CNRM.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1.ALADIN63.v2.mon.pr.v20190510|esg1.umr-cnrm.fr ---> done!
# downloading 36 of 48: cordex.output.EUR-11.CNRM.MOHC-HadGEM2-ES.historical.r1i1p1.ALADIN63.v1.mon.pr.v20190919|esg1.umr-cnrm.fr ---> done!
# downloading 37 of 48: cordex.output.EUR-11.CNRM.MPI-M-MPI-ESM-LR.historical.r1i1p1.ALADIN63.v1.mon.pr.v20200306|esg1.umr-cnrm.fr ---> done!
# downloading 38 of 48: cordex.output.EUR-11.CNRM.NCC-NorESM1-M.historical.r1i1p1.ALADIN63.v1.mon.pr.v20201203|esg1.umr-cnrm.fr ---> done!
# downloading 39 of 48: cordex.output.EUR-11.SMHI.NCC-NorESM1-M.historical.r1i1p1.RCA4.v1.mon.pr.v20180820|esg-dn1.nsc.liu.se ---> done!
# downloading 40 of 48: cordex.output.EUR-11.SMHI.ICHEC-EC-EARTH.historical.r1i1p1.RCA4.v1.mon.pr.v20190820|esg-dn1.nsc.liu.se ---> done!
# downloading 41 of 48: cordex.output.EUR-11.ICTP.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1.RegCM4-6.v2.mon.pr.v20190502|esgf-ictp.hpc.cineca.it ---> done!
# downloading 42 of 48: cordex.output.EUR-11.ICTP.NCC-NorESM1-M.historical.r1i1p1.RegCM4-6.v1.mon.pr.v20190502|esgf-ictp.hpc.cineca.it ---> done!
# downloading 43 of 48: cordex.output.EUR-11.ICTP.MPI-M-MPI-ESM-LR.historical.r1i1p1.RegCM4-6.v1.mon.pr.v20190502|esgf-ictp.hpc.cineca.it ---> done!
# downloading 44 of 48: cordex.output.EUR-11.SMHI.MOHC-HadGEM2-ES.historical.r1i1p1.RCA4.v1.mon.pr.v20131026|esg-dn1.nsc.liu.se ---> done!
# downloading 45 of 48: cordex.output.EUR-11.SMHI.IPSL-IPSL-CM5A-MR.historical.r1i1p1.RCA4.v1.mon.pr.v20131026|esg-dn1.nsc.liu.se ---> done!
# downloading 46 of 48: cordex.output.EUR-11.SMHI.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1.RCA4.v1.mon.pr.v20131026|esg-dn1.nsc.liu.se ---> done!
# downloading 47 of 48: cordex.output.EUR-11.SMHI.MPI-M-MPI-ESM-LR.historical.r1i1p1.RCA4.v1a.mon.pr.v20160803|esg-dn1.nsc.liu.se ---> done!
# downloading 48 of 48: cordex.output.EUR-11.ICTP.MOHC-HadGEM2-ES.historical.r1i1p1.RegCM4-6.v1.mon.pr.v20190502|esgf-ictp.hpc.cineca.it ---> done!
#
# successfully downloaded 48 of 48 datasets
#
# downloading next config: CORDEX EUR-11 rcp26 tas mon r1i1p1 (23 total datasets)
# downloading 1 of 23: cordex.output.EUR-11.KNMI.MOHC-HadGEM2-ES.rcp26.r1i1p1.RACMO22E.v2.mon.tas.v20160830|esgf1.dkrz.de ---> done!
# downloading 2 of 23: cordex.output.EUR-11.MPI-CSC.MPI-M-MPI-ESM-LR.rcp26.r1i1p1.REMO2009.v1.mon.tas.v20160525|esgf1.dkrz.de ---> done!
# downloading 3 of 23: cordex.output.EUR-11.RMIB-UGent.CNRM-CERFACS-CNRM-CM5.rcp26.r1i1p1.ALARO-0.v1.mon.tas.v20170207|esgf1.dkrz.de ---> done!
# downloading 4 of 23: cordex.output.EUR-11.GERICS.IPSL-IPSL-CM5A-LR.rcp26.r1i1p1.REMO2015.v1.mon.tas.v20180710|esgf1.dkrz.de ---> done!
# downloading 5 of 23: cordex.output.EUR-11.CLMcom.MIROC-MIROC5.rcp26.r1i1p1.CCLM4-8-17.v1.mon.tas.v20180707|esgf.dwd.de ---> done!
# downloading 6 of 23: cordex.output.EUR-11.GERICS.MIROC-MIROC5.rcp26.r1i1p1.REMO2015.v1.mon.tas.v20180710|esgf1.dkrz.de ---> done!
# downloading 7 of 23: cordex.output.EUR-11.GERICS.NOAA-GFDL-GFDL-ESM2G.rcp26.r1i1p1.REMO2015.v1.mon.tas.v20180710|esgf1.dkrz.de ---> done!
# downloading 8 of 23: cordex.output.EUR-11.GERICS.MOHC-HadGEM2-ES.rcp26.r1i1p1.REMO2015.v1.mon.tas.v20180710|esgf1.dkrz.de ---> done!
# downloading 9 of 23: cordex.output.EUR-11.KNMI.CNRM-CERFACS-CNRM-CM5.rcp26.r1i1p1.RACMO22E.v2.mon.tas.v20190418|esgf1.dkrz.de ---> done!
# downloading 10 of 23: cordex.output.EUR-11.GERICS.NCC-NorESM1-M.rcp26.r1i1p1.REMO2015.v1.mon.tas.v20190925|esgf1.dkrz.de ---> done!
# downloading 11 of 23: cordex.output.EUR-11.GERICS.CNRM-CERFACS-CNRM-CM5.rcp26.r1i1p1.REMO2015.v2.mon.tas.v20200925|esgf1.dkrz.de ---> done!
# downloading 12 of 23: cordex.output.EUR-11.DMI.MOHC-HadGEM2-ES.rcp26.r1i1p1.HIRHAM5.v2.mon.tas.v20200229|cordexesg.dmi.dk ---> done!
# downloading 13 of 23: cordex.output.EUR-11.KNMI.MPI-M-MPI-ESM-LR.rcp26.r1i1p1.RACMO22E.v1.mon.tas.v20200623|esgf1.dkrz.de ---> done!
# downloading 14 of 23: cordex.output.EUR-11.KNMI.NCC-NorESM1-M.rcp26.r1i1p1.RACMO22E.v1.mon.tas.v20200515|esgf1.dkrz.de ---> done!
# downloading 15 of 23: cordex.output.EUR-11.MOHC.MOHC-HadGEM2-ES.rcp26.r1i1p1.HadREM3-GA7-05.v1.mon.tas.v20201111|esgf.ceda.ac.uk ---> done!
# downloading 16 of 23: cordex.output.EUR-11.CNRM.CNRM-CERFACS-CNRM-CM5.rcp26.r1i1p1.ALADIN53.v1.mon.tas.v20150127|esg1.umr-cnrm.fr ---> done!
# downloading 17 of 23: cordex.output.EUR-11.CNRM.CNRM-CERFACS-CNRM-CM5.rcp26.r1i1p1.ALADIN63.v2.mon.tas.v20190702|esg1.umr-cnrm.fr ---> done!
# downloading 18 of 23: cordex.output.EUR-11.SMHI.MPI-M-MPI-ESM-LR.rcp26.r1i1p1.RCA4.v1a.mon.tas.v20170504|esg-dn1.nsc.liu.se ---> done!
# downloading 19 of 23: cordex.output.EUR-11.SMHI.NCC-NorESM1-M.rcp26.r1i1p1.RCA4.v1.mon.tas.v20190115|esg-dn1.nsc.liu.se ---> done!
# downloading 20 of 23: cordex.output.EUR-11.ICTP.MPI-M-MPI-ESM-LR.rcp26.r1i1p1.RegCM4-6.v1.mon.tas.v20190502|esgf-ictp.hpc.cineca.it ---> done!
# downloading 21 of 23: cordex.output.EUR-11.SMHI.MOHC-HadGEM2-ES.rcp26.r1i1p1.RCA4.v1.mon.tas.v20170504|esg-dn1.nsc.liu.se ---> done!
# downloading 22 of 23: cordex.output.EUR-11.ICTP.NCC-NorESM1-M.rcp26.r1i1p1.RegCM4-6.v1.mon.tas.v20190502|esgf-ictp.hpc.cineca.it ---> done!
# downloading 23 of 23: cordex.output.EUR-11.ICTP.MOHC-HadGEM2-ES.rcp26.r1i1p1.RegCM4-6.v1.mon.tas.v20190502|esgf-ictp.hpc.cineca.it ---> done!
#
# successfully downloaded 23 of 23 datasets
#
# downloading next config: CORDEX EUR-11 rcp26 pr mon r1i1p1 (23 total datasets)
# downloading 1 of 23: cordex.output.EUR-11.KNMI.MOHC-HadGEM2-ES.rcp26.r1i1p1.RACMO22E.v2.mon.pr.v20160830|esgf1.dkrz.de ---> done!
# downloading 2 of 23: cordex.output.EUR-11.MPI-CSC.MPI-M-MPI-ESM-LR.rcp26.r1i1p1.REMO2009.v1.mon.pr.v20160525|esgf1.dkrz.de ---> done!
# downloading 3 of 23: cordex.output.EUR-11.RMIB-UGent.CNRM-CERFACS-CNRM-CM5.rcp26.r1i1p1.ALARO-0.v1.mon.pr.v20170207|esgf1.dkrz.de ---> done!
# downloading 4 of 23: cordex.output.EUR-11.GERICS.NOAA-GFDL-GFDL-ESM2G.rcp26.r1i1p1.REMO2015.v1.mon.pr.v20180710|esgf1.dkrz.de ---> done!
# downloading 5 of 23: cordex.output.EUR-11.GERICS.MIROC-MIROC5.rcp26.r1i1p1.REMO2015.v1.mon.pr.v20180710|esgf1.dkrz.de ---> done!
# downloading 6 of 23: cordex.output.EUR-11.GERICS.IPSL-IPSL-CM5A-LR.rcp26.r1i1p1.REMO2015.v1.mon.pr.v20180710|esgf1.dkrz.de ---> done!
# downloading 7 of 23: cordex.output.EUR-11.CLMcom.MIROC-MIROC5.rcp26.r1i1p1.CCLM4-8-17.v1.mon.pr.v20180707|esgf.dwd.de ---> done!
# downloading 8 of 23: cordex.output.EUR-11.GERICS.MOHC-HadGEM2-ES.rcp26.r1i1p1.REMO2015.v1.mon.pr.v20180710|esgf1.dkrz.de ---> done!
# downloading 9 of 23: cordex.output.EUR-11.KNMI.CNRM-CERFACS-CNRM-CM5.rcp26.r1i1p1.RACMO22E.v2.mon.pr.v20190418|esgf1.dkrz.de ---> done!
# downloading 10 of 23: cordex.output.EUR-11.GERICS.NCC-NorESM1-M.rcp26.r1i1p1.REMO2015.v1.mon.pr.v20190925|esgf1.dkrz.de ---> done!
# downloading 11 of 23: cordex.output.EUR-11.GERICS.CNRM-CERFACS-CNRM-CM5.rcp26.r1i1p1.REMO2015.v2.mon.pr.v20200925|esgf1.dkrz.de ---> done!
# downloading 12 of 23: cordex.output.EUR-11.DMI.MOHC-HadGEM2-ES.rcp26.r1i1p1.HIRHAM5.v2.mon.pr.v20200229|cordexesg.dmi.dk ---> done!
# downloading 13 of 23: cordex.output.EUR-11.KNMI.MPI-M-MPI-ESM-LR.rcp26.r1i1p1.RACMO22E.v1.mon.pr.v20200623|esgf1.dkrz.de ---> done!
# downloading 14 of 23: cordex.output.EUR-11.KNMI.NCC-NorESM1-M.rcp26.r1i1p1.RACMO22E.v1.mon.pr.v20200515|esgf1.dkrz.de ---> done!
# downloading 15 of 23: cordex.output.EUR-11.MOHC.MOHC-HadGEM2-ES.rcp26.r1i1p1.HadREM3-GA7-05.v1.mon.pr.v20201111|esgf.ceda.ac.uk ---> done!
# downloading 16 of 23: cordex.output.EUR-11.CNRM.CNRM-CERFACS-CNRM-CM5.rcp26.r1i1p1.ALADIN53.v1.mon.pr.v20150127|esg1.umr-cnrm.fr ---> done!
# downloading 17 of 23: cordex.output.EUR-11.CNRM.CNRM-CERFACS-CNRM-CM5.rcp26.r1i1p1.ALADIN63.v2.mon.pr.v20190702|esg1.umr-cnrm.fr ---> done!
# downloading 18 of 23: cordex.output.EUR-11.SMHI.MPI-M-MPI-ESM-LR.rcp26.r1i1p1.RCA4.v1a.mon.pr.v20170504|esg-dn1.nsc.liu.se ---> done!
# downloading 19 of 23: cordex.output.EUR-11.SMHI.NCC-NorESM1-M.rcp26.r1i1p1.RCA4.v1.mon.pr.v20190115|esg-dn1.nsc.liu.se ---> done!
# downloading 20 of 23: cordex.output.EUR-11.ICTP.MPI-M-MPI-ESM-LR.rcp26.r1i1p1.RegCM4-6.v1.mon.pr.v20190502|esgf-ictp.hpc.cineca.it ---> done!
# downloading 21 of 23: cordex.output.EUR-11.SMHI.MOHC-HadGEM2-ES.rcp26.r1i1p1.RCA4.v1.mon.pr.v20170504|esg-dn1.nsc.liu.se ---> done!
# downloading 22 of 23: cordex.output.EUR-11.ICTP.NCC-NorESM1-M.rcp26.r1i1p1.RegCM4-6.v1.mon.pr.v20190502|esgf-ictp.hpc.cineca.it ---> done!
# downloading 23 of 23: cordex.output.EUR-11.ICTP.MOHC-HadGEM2-ES.rcp26.r1i1p1.RegCM4-6.v1.mon.pr.v20190502|esgf-ictp.hpc.cineca.it ---> done!
#
# successfully downloaded 23 of 23 datasets
#
# downloading next config: CORDEX EUR-11 rcp85 tas mon r1i1p1 (46 total datasets)
# downloading 1 of 46: cordex.output.EUR-11.CLMcom.MPI-M-MPI-ESM-LR.rcp85.r1i1p1.CCLM4-8-17.v1.mon.tas.v20140515|esgf1.dkrz.de ---> done!
# downloading 2 of 46: cordex.output.EUR-11.CLMcom.MOHC-HadGEM2-ES.rcp85.r1i1p1.CCLM4-8-17.v1.mon.tas.v20150320|esgf1.dkrz.de ---> done!
# downloading 3 of 46: cordex.output.EUR-11.KNMI.ICHEC-EC-EARTH.rcp85.r1i1p1.RACMO22E.v1.mon.tas.v20140324|esgf1.dkrz.de ---> done!
# downloading 4 of 46: cordex.output.EUR-11.CLMcom.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1.CCLM4-8-17.v1.mon.tas.v20140515|esgf1.dkrz.de ---> done!
# downloading 5 of 46: cordex.output.EUR-11.KNMI.MOHC-HadGEM2-ES.rcp85.r1i1p1.RACMO22E.v2.mon.tas.v20160705|esgf1.dkrz.de ---> done!
# downloading 6 of 46: cordex.output.EUR-11.MPI-CSC.MPI-M-MPI-ESM-LR.rcp85.r1i1p1.REMO2009.v1.mon.tas.v20160525|esgf1.dkrz.de ---> done!
# downloading 7 of 46: cordex.output.EUR-11.RMIB-UGent.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1.ALARO-0.v1.mon.tas.v20170207|esgf1.dkrz.de ---> done!
# downloading 8 of 46: cordex.output.EUR-11.UHOH.MPI-M-MPI-ESM-LR.rcp85.r1i1p1.WRF361H.v1.mon.tas.v20170524|esgf1.dkrz.de ---> done!
# downloading 9 of 46: cordex.output.EUR-11.GERICS.NCC-NorESM1-M.rcp85.r1i1p1.REMO2015.v1.mon.tas.v20181212|esgf1.dkrz.de ---> done!
# downloading 10 of 46: cordex.output.EUR-11.KNMI.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1.RACMO22E.v2.mon.tas.v20181212|esgf1.dkrz.de ---> done!
# downloading 11 of 46: cordex.output.EUR-11.KNMI.MPI-M-MPI-ESM-LR.rcp85.r1i1p1.RACMO22E.v1.mon.tas.v20190625|esgf1.dkrz.de ---> done!
# downloading 12 of 46: cordex.output.EUR-11.DMI.NCC-NorESM1-M.rcp85.r1i1p1.HIRHAM5.v3.mon.tas.v20190522|cordexesg.dmi.dk ---> done!
# downloading 13 of 46: cordex.output.EUR-11.DMI.MOHC-HadGEM2-ES.rcp85.r1i1p1.HIRHAM5.v2.mon.tas.v20190512|cordexesg.dmi.dk ---> done!
# downloading 14 of 46: cordex.output.EUR-11.DMI.ICHEC-EC-EARTH.rcp85.r1i1p1.HIRHAM5.v1.mon.tas.v20190108|cordexesg.dmi.dk ---> done!
# downloading 15 of 46: cordex.output.EUR-11.DMI.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1.HIRHAM5.v2.mon.tas.v20190208|cordexesg.dmi.dk ---> done!
# downloading 16 of 46: cordex.output.EUR-11.KNMI.NCC-NorESM1-M.rcp85.r1i1p1.RACMO22E.v1.mon.tas.v20190412|esgf1.dkrz.de ---> done!
# downloading 17 of 46: cordex.output.EUR-11.CLMcom-ETH.NCC-NorESM1-M.rcp85.r1i1p1.COSMO-crCLIM-v1-1.v1.mon.tas.v20191217|esgf1.dkrz.de ---> done!
# downloading 18 of 46: cordex.output.EUR-11.CLMcom-ETH.MPI-M-MPI-ESM-LR.rcp85.r1i1p1.COSMO-crCLIM-v1-1.v1.mon.tas.v20200102|esgf1.dkrz.de ---> done!
# downloading 19 of 46: cordex.output.EUR-11.DMI.MPI-M-MPI-ESM-LR.rcp85.r1i1p1.HIRHAM5.v1.mon.tas.v20200113|cordexesg.dmi.dk ---> done!
# downloading 20 of 46: cordex.output.EUR-11.GERICS.IPSL-IPSL-CM5A-MR.rcp85.r1i1p1.REMO2015.v1.mon.tas.v20200925|esgf1.dkrz.de ---> done!
# downloading 21 of 46: cordex.output.EUR-11.CLMcom-ETH.MOHC-HadGEM2-ES.rcp85.r1i1p1.COSMO-crCLIM-v1-1.v1.mon.tas.v20200924|esgf1.dkrz.de ---> done!
# downloading 22 of 46: cordex.output.EUR-11.GERICS.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1.REMO2015.v2.mon.tas.v20200925|esgf1.dkrz.de ---> done!
# downloading 23 of 46: cordex.output.EUR-11.KNMI.IPSL-IPSL-CM5A-MR.rcp85.r1i1p1.RACMO22E.v1.mon.tas.v20191029|esgf1.dkrz.de ---> done!
# downloading 24 of 46: cordex.output.EUR-11.DMI.IPSL-IPSL-CM5A-MR.rcp85.r1i1p1.HIRHAM5.v1.mon.tas.v20201101|cordexesg.dmi.dk ---> done!
# downloading 25 of 46: cordex.output.EUR-11.CLMcom-ETH.ICHEC-EC-EARTH.rcp85.r1i1p1.COSMO-crCLIM-v1-1.v1.mon.tas.v20210128|esgf1.dkrz.de ---> done!
# downloading 26 of 46: cordex.output.EUR-11.CLMcom-ETH.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1.COSMO-crCLIM-v1-1.v1.mon.tas.v20210430|esgf1.dkrz.de ---> done!
# downloading 27 of 46: cordex.output.EUR-11.MOHC.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1.HadREM3-GA7-05.v2.mon.tas.v20210113|esgf.ceda.ac.uk ---> done!
# downloading 28 of 46: cordex.output.EUR-11.MOHC.MOHC-HadGEM2-ES.rcp85.r1i1p1.HadREM3-GA7-05.v1.mon.tas.v20191005|esgf.ceda.ac.uk ---> done!
# downloading 29 of 46: cordex.output.EUR-11.MOHC.MOHC-HadGEM2-ES.rcp85.r1i1p1.HadREM3-GA7-05.v1.mon.tas.v20200330|esgf.ceda.ac.uk ---> done!
# downloading 30 of 46: cordex.output.EUR-11.MOHC.MPI-M-MPI-ESM-LR.rcp85.r1i1p1.HadREM3-GA7-05.v1.mon.tas.v20200706|esgf.ceda.ac.uk ---> done!
# downloading 31 of 46: cordex.output.EUR-11.MOHC.NCC-NorESM1-M.rcp85.r1i1p1.HadREM3-GA7-05.v1.mon.tas.v20201111|esgf.ceda.ac.uk ---> done!
# downloading 32 of 46: cordex.output.EUR-11.CNRM.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1.ALADIN53.v1.mon.tas.v20150127|esg1.umr-cnrm.fr ---> done!
# downloading 33 of 46: cordex.output.EUR-11.CNRM.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1.ALADIN63.v2.mon.tas.v20190419|esg1.umr-cnrm.fr ---> done!
# downloading 34 of 46: cordex.output.EUR-11.CNRM.MOHC-HadGEM2-ES.rcp85.r1i1p1.ALADIN63.v1.mon.tas.v20191004|esg1.umr-cnrm.fr ---> done!
# downloading 35 of 46: cordex.output.EUR-11.CNRM.MPI-M-MPI-ESM-LR.rcp85.r1i1p1.ALADIN63.v1.mon.tas.v20200518|esg1.umr-cnrm.fr ---> done!
# downloading 36 of 46: cordex.output.EUR-11.CNRM.NCC-NorESM1-M.rcp85.r1i1p1.ALADIN63.v1.mon.tas.v20201112|esg1.umr-cnrm.fr ---> done!
# downloading 37 of 46: cordex.output.EUR-11.SMHI.NCC-NorESM1-M.rcp85.r1i1p1.RCA4.v1.mon.tas.v20180820|esg-dn1.nsc.liu.se ---> done!
# downloading 38 of 46: cordex.output.EUR-11.SMHI.ICHEC-EC-EARTH.rcp85.r1i1p1.RCA4.v1.mon.tas.v20190820|esg-dn1.nsc.liu.se ---> done!
# downloading 39 of 46: cordex.output.EUR-11.ICTP.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1.RegCM4-6.v2.mon.tas.v20190502|esgf-ictp.hpc.cineca.it ---> done!
# downloading 40 of 46: cordex.output.EUR-11.ICTP.MOHC-HadGEM2-ES.rcp85.r1i1p1.RegCM4-6.v1.mon.tas.v20190502|esgf-ictp.hpc.cineca.it ---> done!
# downloading 41 of 46: cordex.output.EUR-11.SMHI.MPI-M-MPI-ESM-LR.rcp85.r1i1p1.RCA4.v1a.mon.tas.v20160803|esg-dn1.nsc.liu.se ---> done!
# downloading 42 of 46: cordex.output.EUR-11.SMHI.MOHC-HadGEM2-ES.rcp85.r1i1p1.RCA4.v1.mon.tas.v20131026|esg-dn1.nsc.liu.se ---> done!
# downloading 43 of 46: cordex.output.EUR-11.SMHI.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1.RCA4.v1.mon.tas.v20131026|esg-dn1.nsc.liu.se ---> done!
# downloading 44 of 46: cordex.output.EUR-11.SMHI.IPSL-IPSL-CM5A-MR.rcp85.r1i1p1.RCA4.v1.mon.tas.v20131026|esg-dn1.nsc.liu.se ---> done!
# downloading 45 of 46: cordex.output.EUR-11.ICTP.NCC-NorESM1-M.rcp85.r1i1p1.RegCM4-6.v1.mon.tas.v20190502|esgf-ictp.hpc.cineca.it ---> done!
# downloading 46 of 46: cordex.output.EUR-11.ICTP.MPI-M-MPI-ESM-LR.rcp85.r1i1p1.RegCM4-6.v1.mon.tas.v20190502|esgf-ictp.hpc.cineca.it ---> done!
#
# successfully downloaded 46 of 46 datasets
#
# downloading next config: CORDEX EUR-11 rcp85 pr mon r1i1p1 (46 total datasets)
# downloading 1 of 46: cordex.output.EUR-11.CLMcom.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1.CCLM4-8-17.v1.mon.pr.v20140515|esgf1.dkrz.de ---> done!
# downloading 2 of 46: cordex.output.EUR-11.CLMcom.MOHC-HadGEM2-ES.rcp85.r1i1p1.CCLM4-8-17.v1.mon.pr.v20150320|esgf1.dkrz.de ---> done!
# downloading 3 of 46: cordex.output.EUR-11.CLMcom.MPI-M-MPI-ESM-LR.rcp85.r1i1p1.CCLM4-8-17.v1.mon.pr.v20140515|esgf1.dkrz.de ---> done!
# downloading 4 of 46: cordex.output.EUR-11.KNMI.ICHEC-EC-EARTH.rcp85.r1i1p1.RACMO22E.v1.mon.pr.v20140324|esgf1.dkrz.de ---> done!
# downloading 5 of 46: cordex.output.EUR-11.KNMI.MOHC-HadGEM2-ES.rcp85.r1i1p1.RACMO22E.v2.mon.pr.v20160705|esgf1.dkrz.de ---> done!
# downloading 6 of 46: cordex.output.EUR-11.MPI-CSC.MPI-M-MPI-ESM-LR.rcp85.r1i1p1.REMO2009.v1.mon.pr.v20160525|esgf1.dkrz.de ---> done!
# downloading 7 of 46: cordex.output.EUR-11.RMIB-UGent.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1.ALARO-0.v1.mon.pr.v20170207|esgf1.dkrz.de ---> done!
# downloading 8 of 46: cordex.output.EUR-11.GERICS.NCC-NorESM1-M.rcp85.r1i1p1.REMO2015.v1.mon.pr.v20181212|esgf1.dkrz.de ---> done!
# downloading 9 of 46: cordex.output.EUR-11.KNMI.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1.RACMO22E.v2.mon.pr.v20181212|esgf1.dkrz.de ---> done!
# downloading 10 of 46: cordex.output.EUR-11.KNMI.MPI-M-MPI-ESM-LR.rcp85.r1i1p1.RACMO22E.v1.mon.pr.v20190625|esgf1.dkrz.de ---> done!
# downloading 11 of 46: cordex.output.EUR-11.UHOH.MPI-M-MPI-ESM-LR.rcp85.r1i1p1.WRF361H.v1.mon.pr.v20170524|esgf1.dkrz.de ---> done!
# downloading 12 of 46: cordex.output.EUR-11.DMI.MOHC-HadGEM2-ES.rcp85.r1i1p1.HIRHAM5.v2.mon.pr.v20190512|cordexesg.dmi.dk ---> done!
# downloading 13 of 46: cordex.output.EUR-11.DMI.NCC-NorESM1-M.rcp85.r1i1p1.HIRHAM5.v3.mon.pr.v20190522|cordexesg.dmi.dk ---> done!
# downloading 14 of 46: cordex.output.EUR-11.DMI.ICHEC-EC-EARTH.rcp85.r1i1p1.HIRHAM5.v1.mon.pr.v20190108|cordexesg.dmi.dk ---> done!
# downloading 15 of 46: cordex.output.EUR-11.DMI.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1.HIRHAM5.v2.mon.pr.v20190208|cordexesg.dmi.dk ---> done!
# downloading 16 of 46: cordex.output.EUR-11.KNMI.NCC-NorESM1-M.rcp85.r1i1p1.RACMO22E.v1.mon.pr.v20190412|esgf1.dkrz.de ---> done!
# downloading 17 of 46: cordex.output.EUR-11.CLMcom-ETH.NCC-NorESM1-M.rcp85.r1i1p1.COSMO-crCLIM-v1-1.v1.mon.pr.v20191217|esgf1.dkrz.de ---> done!
# downloading 18 of 46: cordex.output.EUR-11.CLMcom-ETH.MPI-M-MPI-ESM-LR.rcp85.r1i1p1.COSMO-crCLIM-v1-1.v1.mon.pr.v20200102|esgf1.dkrz.de ---> done!
# downloading 19 of 46: cordex.output.EUR-11.DMI.MPI-M-MPI-ESM-LR.rcp85.r1i1p1.HIRHAM5.v1.mon.pr.v20200113|cordexesg.dmi.dk ---> done!
# downloading 20 of 46: cordex.output.EUR-11.CLMcom-ETH.MOHC-HadGEM2-ES.rcp85.r1i1p1.COSMO-crCLIM-v1-1.v1.mon.pr.v20200924|esgf1.dkrz.de ---> done!
# downloading 21 of 46: cordex.output.EUR-11.GERICS.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1.REMO2015.v2.mon.pr.v20200925|esgf1.dkrz.de ---> done!
# downloading 22 of 46: cordex.output.EUR-11.GERICS.IPSL-IPSL-CM5A-MR.rcp85.r1i1p1.REMO2015.v1.mon.pr.v20200925|esgf1.dkrz.de ---> done!
# downloading 23 of 46: cordex.output.EUR-11.KNMI.IPSL-IPSL-CM5A-MR.rcp85.r1i1p1.RACMO22E.v1.mon.pr.v20191029|esgf1.dkrz.de ---> done!
# downloading 24 of 46: cordex.output.EUR-11.DMI.IPSL-IPSL-CM5A-MR.rcp85.r1i1p1.HIRHAM5.v1.mon.pr.v20201101|cordexesg.dmi.dk ---> done!
# downloading 25 of 46: cordex.output.EUR-11.CLMcom-ETH.ICHEC-EC-EARTH.rcp85.r1i1p1.COSMO-crCLIM-v1-1.v1.mon.pr.v20210128|esgf1.dkrz.de ---> done!
# downloading 26 of 46: cordex.output.EUR-11.CLMcom-ETH.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1.COSMO-crCLIM-v1-1.v1.mon.pr.v20210430|esgf1.dkrz.de ---> done!
# downloading 27 of 46: cordex.output.EUR-11.MOHC.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1.HadREM3-GA7-05.v2.mon.pr.v20210113|esgf.ceda.ac.uk ---> done!
# downloading 28 of 46: cordex.output.EUR-11.MOHC.MOHC-HadGEM2-ES.rcp85.r1i1p1.HadREM3-GA7-05.v1.mon.pr.v20191005|esgf.ceda.ac.uk ---> done!
# downloading 29 of 46: cordex.output.EUR-11.MOHC.MOHC-HadGEM2-ES.rcp85.r1i1p1.HadREM3-GA7-05.v1.mon.pr.v20200330|esgf.ceda.ac.uk ---> done!
# downloading 30 of 46: cordex.output.EUR-11.MOHC.MPI-M-MPI-ESM-LR.rcp85.r1i1p1.HadREM3-GA7-05.v1.mon.pr.v20200706|esgf.ceda.ac.uk ---> done!
# downloading 31 of 46: cordex.output.EUR-11.MOHC.NCC-NorESM1-M.rcp85.r1i1p1.HadREM3-GA7-05.v1.mon.pr.v20201111|esgf.ceda.ac.uk ---> done!
# downloading 32 of 46: cordex.output.EUR-11.CNRM.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1.ALADIN53.v1.mon.pr.v20150127|esg1.umr-cnrm.fr ---> done!
# downloading 33 of 46: cordex.output.EUR-11.CNRM.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1.ALADIN63.v2.mon.pr.v20190419|esg1.umr-cnrm.fr ---> done!
# downloading 34 of 46: cordex.output.EUR-11.CNRM.MOHC-HadGEM2-ES.rcp85.r1i1p1.ALADIN63.v1.mon.pr.v20191004|esg1.umr-cnrm.fr ---> done!
# downloading 35 of 46: cordex.output.EUR-11.CNRM.MPI-M-MPI-ESM-LR.rcp85.r1i1p1.ALADIN63.v1.mon.pr.v20200518|esg1.umr-cnrm.fr ---> done!
# downloading 36 of 46: cordex.output.EUR-11.CNRM.NCC-NorESM1-M.rcp85.r1i1p1.ALADIN63.v1.mon.pr.v20201112|esg1.umr-cnrm.fr ---> done!
# downloading 37 of 46: cordex.output.EUR-11.SMHI.NCC-NorESM1-M.rcp85.r1i1p1.RCA4.v1.mon.pr.v20180820|esg-dn1.nsc.liu.se ---> done!
# downloading 38 of 46: cordex.output.EUR-11.SMHI.ICHEC-EC-EARTH.rcp85.r1i1p1.RCA4.v1.mon.pr.v20190820|esg-dn1.nsc.liu.se ---> done!
# downloading 39 of 46: cordex.output.EUR-11.ICTP.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1.RegCM4-6.v2.mon.pr.v20190502|esgf-ictp.hpc.cineca.it ---> done!
# downloading 40 of 46: cordex.output.EUR-11.ICTP.MOHC-HadGEM2-ES.rcp85.r1i1p1.RegCM4-6.v1.mon.pr.v20190502|esgf-ictp.hpc.cineca.it ---> done!
# downloading 41 of 46: cordex.output.EUR-11.SMHI.MPI-M-MPI-ESM-LR.rcp85.r1i1p1.RCA4.v1a.mon.pr.v20160803|esg-dn1.nsc.liu.se ---> done!
# downloading 42 of 46: cordex.output.EUR-11.SMHI.MOHC-HadGEM2-ES.rcp85.r1i1p1.RCA4.v1.mon.pr.v20131026|esg-dn1.nsc.liu.se ---> done!
# downloading 43 of 46: cordex.output.EUR-11.SMHI.IPSL-IPSL-CM5A-MR.rcp85.r1i1p1.RCA4.v1.mon.pr.v20131026|esg-dn1.nsc.liu.se ---> done!
# downloading 44 of 46: cordex.output.EUR-11.SMHI.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1.RCA4.v1.mon.pr.v20131026|esg-dn1.nsc.liu.se ---> done!
# downloading 45 of 46: cordex.output.EUR-11.ICTP.NCC-NorESM1-M.rcp85.r1i1p1.RegCM4-6.v1.mon.pr.v20190502|esgf-ictp.hpc.cineca.it ---> done!
# downloading 46 of 46: cordex.output.EUR-11.ICTP.MPI-M-MPI-ESM-LR.rcp85.r1i1p1.RegCM4-6.v1.mon.pr.v20190502|esgf-ictp.hpc.cineca.it ---> done!
#
# successfully downloaded 46 of 46 datasets
#
# all downloads now complete. successfully downloaded 234 out of 234 datasets.
# a full list of datasets omitted due to errors is available below:
